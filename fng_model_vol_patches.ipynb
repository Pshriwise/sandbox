# %%
from yt.mods import *
import h5py
import os

# %%
# If necessary files aren't in the current dir, download them
if not os.path.isfile("mcnp_n_impr_fluka.h5m"):
    from urllib import urlretrieve
    urlretrieve("http://data.pyne.io/mcnp_n_impr_fluka.h5m", "mcnp_n_impr_fluka.h5m")
    
if not os.path.isfile("fng_usrbin22.h5m"):
    # fng_usrbin22.h5m is a large file
    # needs to be downloaded in chunks
    import requests
    r = requests.get("http://data.pyne.io/fng_usrbin22.h5m", stream=True)
    with open("fng_usrbin22.h5m" , 'wb') as file:
        for chunk in r.iter_content(chunk_size=1024):
            if chunk:
                file.write(chunk)
                file.flush()

# %%
# Load data file
pf = load("fng_usrbin22.h5m")

# %%
# Create the desired slice plot
s = SlicePlot(pf, 'z', ('moab','TALLY_TAG'), origin='lower-native')
# Load the facet file
#f = h5py.File("mcnp_n_impr_fluka.h5m", "r")
# Get the triangle vertices
#coords = f["/tstt/nodes/coordinates"][:]
#conn = f["/tstt/elements/Tri3/connectivity"][:]
#points = coords[conn-1]
# Annotate slice-triangle intersection contours to the plot
s.annotate_triangle_facets('mcnp_n_impr_fluka_zip.h5m', plot_args={"colors": 'black'})
s.display()
# Out:
# There are 644 surfaces in this model.
# There are 122 volumes in this model.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 16 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 16 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 34 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 15 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 15 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 13 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 46 intersections for this volume.
# Found 2 poly collections for this volume.
# <img src="data:image/png;base64,..."><br>

# %%
s.zoom(1.1)
# Out:
# There are 1288 surfaces in this model.
# There are 244 volumes in this model.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 16 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 16 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 34 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 15 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 15 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 13 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 46 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 3 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 16 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 14 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 12 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 16 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 34 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 15 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 15 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 13 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 8 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 10 intersections for this volume.
# Found 2 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 5 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 6 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 4 intersections for this volume.
# Found 1 poly collections for this volume.
# Retrieved 46 intersections for this volume.
# Found 2 poly collections for this volume.
# <img src="data:image/png;base64,..."><br>

# %%
s.save()
# Out:
# ['fng_usrbin22_Slice_z_TALLY_TAG.png']
